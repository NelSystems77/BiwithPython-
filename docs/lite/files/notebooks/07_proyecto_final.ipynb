# %% [markdown]
# # Modulo 7 · Proyecto final: Zero to Hero
#
# ¡Llegaste al proyecto final! Aqui vas a integrar todo lo aprendido en un
# analisis de BI completo, de punta a punta, sobre un dataset nuevo (o el mismo
# de TiendaPy si prefieres profundizar).
#
# ## Objetivo
#
# Construir un **reporte de BI + dashboard** que responda preguntas reales de
# negocio, siguiendo el mismo flujo que usamos en el curso:
#
# ```
# Cargar datos -> Limpiar -> Explorar (EDA) -> Visualizar -> Dashboard
# ```
#
# ## Opcion A: Profundizar en TiendaPy (recomendado si es tu primer proyecto)
#
# Usa `data/ventas.csv` y responde estas preguntas de negocio en un notebook
# nuevo (`notebooks/mi_proyecto.ipynb`):
#
# 1. ¿Cual region deberia recibir mas inversion en marketing segun crecimiento
#    de ingresos mes a mes?
# 2. ¿Que categoria tiene el mejor margen y cual el peor? ¿Por que podria ser?
# 3. ¿Existen vendedores con muchas ventas pero bajo margen (venden con mucho
#    descuento)? Identificalos.
# 4. ¿El segmento `"Corporativo"` genera mas ingreso por venta que `"Individual"`?
#    Compara con un grafico.
# 5. Construye una recomendacion de negocio (3-5 lineas) basada en tus hallazgos.
#
# ## Opcion B: Trae tu propio dataset
#
# Si tienes un CSV propio (ventas, marketing, RRHH, finanzas), aplica el mismo
# flujo:
#
# 1. Cargalo con pandas y explora su estructura.
# 2. Limpialo (nulos, duplicados, tipos).
# 3. Define 3-5 KPIs relevantes para ese dominio.
# 4. Crea al menos 4 visualizaciones distintas.
# 5. Adapta `app/dashboard.py` para que funcione con tu dataset.

# %% [markdown]
# ## Entregables del proyecto final
#
# 1. **Notebook de analisis** (`notebooks/mi_proyecto.ipynb`) con: carga,
#    limpieza, EDA, al menos 4 visualizaciones y conclusiones escritas en
#    celdas markdown.
# 2. **Dashboard interactivo**: una copia adaptada de `app/dashboard.py` que
#    funcione con tu analisis (puede ser el mismo dataset de TiendaPy con
#    nuevas vistas, o tu propio dataset).
# 3. **Resumen ejecutivo**: 5-8 lineas en markdown explicando los hallazgos
#    principales y una recomendacion de negocio, como si se la presentaras a
#    un gerente que no sabe Python.

# %% [markdown]
# ## Rubrica de autoevaluacion
#
# | Criterio | Nivel logrado (marca con X) |
# |---|---|
# | Los datos se cargan y limpian correctamente (sin nulos ni duplicados sin tratar) | [ ] |
# | Se calculan al menos 5 KPIs relevantes | [ ] |
# | Hay al menos 4 visualizaciones distintas, cada una con titulo y ejes claros | [ ] |
# | El dashboard de Streamlit permite filtrar los datos de forma interactiva | [ ] |
# | Las conclusiones estan escritas en lenguaje de negocio (no solo codigo) | [ ] |
# | El codigo esta organizado y comentado donde es necesario | [ ] |

# %%
# Plantilla de inicio para tu proyecto. Copia esta celda a un notebook nuevo
# llamado notebooks/mi_proyecto.ipynb y continua desde aqui.

import pandas as pd
import plotly.express as px

# 1. Cargar datos
df = pd.read_csv("../data/ventas.csv", parse_dates=["fecha"])

# 2. Limpiar datos
df["segmento_cliente"] = df["segmento_cliente"].fillna("Desconocido")
df = df.drop_duplicates()

# 3. Explorar (EDA) - agrega tus propios groupby / pivot_table aqui


# 4. Visualizar - agrega tus propios graficos aqui


# 5. Conclusiones - escribelas en una celda markdown debajo de tu analisis
df.head()
# Out:
#    id_venta      fecha region    categoria            producto  \
# 0         1 2023-01-01   Este     Deportes           Bicicleta
# 1         2 2023-01-01    Sur  Electronica  Parlante Bluetooth
# 2         3 2023-01-01   Este        Hogar          Aspiradora
# 3         4 2023-01-01    Sur        Hogar          Aspiradora
# 4         5 2023-01-01    Sur      Oficina          Escritorio
#
#          vendedor segmento_cliente  unidades  precio_unitario  descuento_pct  \
# 0      Hugo Reyes             Pyme         5         166190.0           0.20
# 1     Bruno Silva       Individual         2          25420.0           0.00
# 2  Gabriela Nunez             Pyme         6          80310.0           0.15
# 3      Hugo Reyes             Pyme         5          77630.0           0.00
# 4     Diego Rojas       Individual         6          97620.0           0.00
#
#     ingreso     costo  utilidad
# 0  664760.0  498570.0  166190.0
# 1   50840.0   30504.0   20336.0
# ...

# %% [markdown]
# ## Siguientes pasos (despues del curso)
#
# Si quieres seguir avanzando en BI con Python, estos son buenos temas para
# continuar:
#
# - **SQL + pandas**: conectar pandas a una base de datos real con `sqlalchemy`.
# - **Automatizacion de reportes**: generar PDFs o Excel automaticamente con
#   `openpyxl` o `reportlab`.
# - **Otras herramientas de BI**: Power BI, Looker Studio o Tableau, para
#   comparar el enfoque "code-first" con herramientas "no-code".
# - **Modelado predictivo**: dar el salto de BI descriptivo a modelos de
#   prediccion de ventas con `scikit-learn`.
#
# ¡Felicidades por completar **BI con Python: Zero to Hero**! 🎉
