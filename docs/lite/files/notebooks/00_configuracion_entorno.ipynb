# %% [markdown]
# # Modulo 0 · Bienvenida y configuracion del entorno
#
# Bienvenido/a a **BI con Python: Zero to Hero**, un curso practico para aprender
# Business Intelligence (BI) y Analisis de Datos usando Python, desde cero hasta
# construir tu propio dashboard interactivo.
#
# ## Que vas a lograr al terminar este curso
#
# 1. Manejar Python con soltura para tareas de analisis de datos.
# 2. Cargar, limpiar y transformar datos reales con **pandas**.
# 3. Explorar datos y calcular indicadores de negocio (KPIs).
# 4. Crear visualizaciones profesionales con **matplotlib**, **seaborn** y **plotly**.
# 5. Construir un **dashboard interactivo** con **Streamlit**.
# 6. Entregar un **proyecto final** de BI de punta a punta.
#
# ## Ruta del curso
#
# | Modulo | Tema | Carpeta |
# |---|---|---|
# | 0 | Configuracion del entorno | `notebooks/00_configuracion_entorno.ipynb` |
# | 1 | Fundamentos de Python para BI | `notebooks/01_fundamentos_python.ipynb` |
# | 2 | Pandas: cargar y explorar datos | `notebooks/02_pandas_basico.ipynb` |
# | 3 | Limpieza y transformacion de datos | `notebooks/03_limpieza_datos.ipynb` |
# | 4 | Analisis exploratorio (EDA) y KPIs | `notebooks/04_analisis_exploratorio.ipynb` |
# | 5 | Visualizacion de datos | `notebooks/05_visualizacion.ipynb` |
# | 6 | Dashboards interactivos con Streamlit | `notebooks/06_dashboard_streamlit.ipynb` |
# | 7 | Proyecto final | `notebooks/07_proyecto_final.ipynb` |
#
# Cada notebook tiene:
# - 📘 **Teoria** explicada con ejemplos aplicados a un caso de negocio real.
# - 💻 **Codigo ejecutable** que puedes correr celda por celda.
# - 🧠 **Retos** para practicar por tu cuenta (con soluciones en `solutions/`).

# %% [markdown]
# ## El caso de negocio: TiendaPy
#
# A lo largo del curso vamos a trabajar con un dataset simulado de **TiendaPy**,
# una cadena retail ficticia con ventas en 5 regiones de Chile, 5 categorias de
# productos y 10 vendedores, durante el periodo 2023-2025.
#
# El dataset esta en `data/ventas.csv`. Si no existe, generalo con:
#
# ```bash
# python scripts/generate_data.py
# ```

# %%
# Verifiquemos que las librerias necesarias esten instaladas
import importlib

paquetes = ["pandas", "numpy", "matplotlib", "seaborn", "plotly", "streamlit"]

for paquete in paquetes:
    try:
        mod = importlib.import_module(paquete)
        version = getattr(mod, "__version__", "version no disponible")
        print(f"OK  {paquete:<12} {version}")
    except ImportError:
        print(f"FALTA {paquete} -> instala con: pip install -r requirements.txt")
# Out:
# OK  pandas       3.0.5
# OK  numpy        2.4.6
# OK  matplotlib   3.11.1
# OK  seaborn      0.13.2
# OK  plotly       7.0.0
# OK  streamlit    1.63.0

# %%
import pandas as pd

df = pd.read_csv("../data/ventas.csv")
print(f"El dataset tiene {df.shape[0]} filas y {df.shape[1]} columnas")
df.head()
# Out:
# El dataset tiene 12030 filas y 13 columnas
#    id_venta       fecha region    categoria            producto  \
# 0         1  2023-01-01   Este     Deportes           Bicicleta
# 1         2  2023-01-01    Sur  Electronica  Parlante Bluetooth
# 2         3  2023-01-01   Este        Hogar          Aspiradora
# 3         4  2023-01-01    Sur        Hogar          Aspiradora
# 4         5  2023-01-01    Sur      Oficina          Escritorio
#
#          vendedor segmento_cliente  unidades  precio_unitario  descuento_pct  \
# 0      Hugo Reyes             Pyme         5         166190.0           0.20
# 1     Bruno Silva       Individual         2          25420.0           0.00
# 2  Gabriela Nunez             Pyme         6          80310.0           0.15
# 3      Hugo Reyes             Pyme         5          77630.0           0.00
# 4     Diego Rojas       Individual         6          97620.0           0.00
#
#     ingreso     costo  utilidad
# 0  664760.0  498570.0  166190.0
# ...

# %% [markdown]
# ## Como usar este curso
#
# **1. Crea un entorno virtual e instala las dependencias:**
#
# ```bash
# python -m venv .venv
# source .venv/bin/activate  # En Windows: .venv\Scripts\activate
# pip install -r requirements.txt
# ```
#
# **2. Genera los datos de practica:**
#
# ```bash
# python scripts/generate_data.py
# ```
#
# **3. Abre Jupyter y sigue los notebooks en orden:**
#
# ```bash
# jupyter notebook notebooks/
# ```
#
# **4. Cuando termines el modulo 6, ejecuta el dashboard final:**
#
# ```bash
# streamlit run app/dashboard.py
# ```
#
# ¡Empecemos! Continua con `01_fundamentos_python.ipynb`.
